# %% [markdown]
# # SCALER WALMART CASE-STUDY

# %% [markdown]
# # PROBLEM STATEMENT

# %%
# IMPORTING LIBRARIES
import pandas as pd
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("walmart_data.csv")
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
df.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                 int64
# Product_Category               int64
# Purchase                       int64
# dtype: object

# %%
a = df.shape
print("the shape of the data is ",a[0], "rows",a[1],"columns")
# Out:
# the shape of the data is  550068 rows 10 columns

# %%
for i in df.columns:
  print(i, ':', df[i].nunique())
# Out:
# User_ID : 5891
# Product_ID : 3631
# Gender : 2
# Age : 7
# Occupation : 21
# City_Category : 3
# Stay_In_Current_City_Years : 5
# Marital_Status : 2
# Product_Category : 20
# Purchase : 18105

# %%
df.isnull().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category',
#        'Purchase'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique().reset_index()
# Out:
#                         index      0
# 0                     User_ID   5891
# 1                  Product_ID   3631
# 2                      Gender      2
# 3                         Age      7
# 4                  Occupation     21
# 5               City_Category      3
# 6  Stay_In_Current_City_Years      5
# 7              Marital_Status      2
# 8            Product_Category     20
# 9                    Purchase  18105

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category  \
# count  5.500680e+05  550068.000000   550068.000000     550068.000000
# mean   1.003029e+06       8.076707        0.409653          5.404270
# std    1.727592e+03       6.522660        0.491770          3.936211
# min    1.000001e+06       0.000000        0.000000          1.000000
# 25%    1.001516e+06       2.000000        0.000000          1.000000
# 50%    1.003077e+06       7.000000        0.000000          5.000000
# 75%    1.004478e+06      14.000000        1.000000          8.000000
# max    1.006040e+06      20.000000        1.000000         20.000000
#
#             Purchase
# count  550068.000000
# mean     9263.968713
# std      5023.065394
# min        12.000000
# 25%      5823.000000
# 50%      8047.000000
# 75%     12054.000000
# max     23961.000000

# %%
df['User_ID'].value_counts().reset_index()
# Out:
#         index  User_ID
# 0     1001680     1026
# 1     1004277      979
# 2     1001941      898
# 3     1001181      862
# 4     1000889      823
# ...       ...      ...
# 5886  1002690        7
# 5887  1002111        7
# 5888  1005810        7
# 5889  1004991        7
# 5890  1000708        6
#
# [5891 rows x 2 columns]

# %%
df['Product_ID'].value_counts().reset_index()
# Out:
#           index  Product_ID
# 0     P00265242        1880
# 1     P00025442        1615
# 2     P00110742        1612
# 3     P00112142        1562
# 4     P00057642        1470
# ...         ...         ...
# 3626  P00314842           1
# 3627  P00298842           1
# 3628  P00231642           1
# 3629  P00204442           1
# 3630  P00066342           1
#
# [3631 rows x 2 columns]

# %%
df['Age'].value_counts().reset_index()
# Out:
#    index     Age
# 0  26-35  219587
# 1  36-45  110013
# 2  18-25   99660
# 3  46-50   45701
# 4  51-55   38501
# 5    55+   21504
# 6   0-17   15102

# %%
df['Occupation'].value_counts().reset_index()
# Out:
#     index  Occupation
# 0       4       72308
# 1       0       69638
# 2       7       59133
# 3       1       47426
# 4      17       40043
# 5      20       33562
# 6      12       31179
# 7      14       27309
# 8       2       26588
# 9      16       25371
# 10      6       20355
# 11      3       17650
# 12     10       12930
# 13      5       12177
# 14     15       12165
# 15     11       11586
# 16     19        8461
# 17     13        7728
# 18     18        6622
# 19      9        6291
# 20      8        1546

# %%
df['City_Category'].value_counts().reset_index()
# Out:
#   index  City_Category
# 0     B         231173
# 1     C         171175
# 2     A         147720

# %%
df['Stay_In_Current_City_Years'].value_counts().reset_index()
# Out:
#   index  Stay_In_Current_City_Years
# 0     1                      193821
# 1     2                      101838
# 2     3                       95285
# 3    4+                       84726
# 4     0                       74398

# %%
df['Marital_Status'].value_counts().reset_index()
# Out:
#    index  Marital_Status
# 0      0          324731
# 1      1          225337

# %%
df['Product_Category'].value_counts().reset_index()
# Out:
#     index  Product_Category
# 0       5            150933
# 1       1            140378
# 2       8            113925
# 3      11             24287
# 4       2             23864
# 5       6             20466
# 6       3             20213
# 7       4             11753
# 8      16              9828
# 9      15              6290
# 10     13              5549
# 11     10              5125
# 12     12              3947
# 13      7              3721
# 14     18              3125
# 15     20              2550
# 16     19              1603
# 17     14              1523
# 18     17               578
# 19      9               410

# %%
df['Purchase'].value_counts().reset_index()
# Out:
#        index  Purchase
# 0       7011       191
# 1       7193       188
# 2       6855       187
# 3       6891       184
# 4       7012       183
# ...      ...       ...
# 18100  23491         1
# 18101  18345         1
# 18102   3372         1
# 18103    855         1
# 18104  21489         1
#
# [18105 rows x 2 columns]

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                          2               0                 3      8370
# 1                          2               0                 1     15200
# 2                          2               0                12      1422
# 3                          2               0                12      1057
# 4                         4+               0                 8      7969

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81bd5190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81b2e590>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81ae0b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81aa51d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81ad97d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f7f81a92dd0>]],
#       dtype=object)

# %%
# # Creating a copy of the dataframe -
# df_copy=df.copy()

# df_copy['Gender'].replace(['Male', 'Female'], [1, 0], inplace=True)

# df_copy['MaritalStatus'].replace(['Single', 'Partnered'], [0, 1], inplace=True)

# df_copy['Product'].replace(['KP281', 'KP481', 'KP781'], [0, 1, 2], inplace=True)

# df_copy.corr()

# %%
df.corr()
# Out:
#                    User_ID  Occupation  Marital_Status  Product_Category  \
# User_ID           1.000000   -0.023971        0.020443          0.003825
# Occupation       -0.023971    1.000000        0.024280         -0.007618
# Marital_Status    0.020443    0.024280        1.000000          0.019888
# Product_Category  0.003825   -0.007618        0.019888          1.000000
# Purchase          0.004716    0.020833       -0.000463         -0.343703
#
#                   Purchase
# User_ID           0.004716
# Occupation        0.020833
# Marital_Status   -0.000463
# Product_Category -0.343703
# Purchase          1.000000

# %%
plt.figure(figsize=(30,5))
sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %%
ax = sns.boxplot(x=df["Purchase"])
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %%
num_feat=['Age', 'Income', 'Miles']
for col in num_feat:
    percentiles = df[col].quantile([0.05,0.95]).values
    df_copy[col] = np.clip(df_copy[col], percentiles[0], percentiles[1])

# %%
plt.scatter(df['Age'], df['Purchase'],
            linewidths = 2,
            marker ="o",
            edgecolor ="green",
            s = 50)

# %%
sns.distplot(df['Age'], hist=True, kde=True, 
bins=int(36), color = 'darkblue', 
hist_kws={'edgecolor':'black'},
kde_kws={'linewidth': 4})
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-1974085765cb> in <module>()
#       2 bins=int(36), color = 'darkblue',
#       3 hist_kws={'edgecolor':'black'},
# ----> 4 kde_kws={'linewidth': 4})
#       5 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2634
#    2635     # Make a a 1-d float array
# -> 2636     a = np.asarray(a, float)
#    2637     if a.ndim > 1:
#    2638         a = a.squeeze()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __array__(self, dtype)
#     855               dtype='datetime64[ns]')
#     856         """
# --> 857         return np.asarray(self._values, dtype)
#     858
#     859     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: '0-17'

# %%
bins = [-1,20,25,30,35,40,55]
labels = ['<20','20-25','25-30','30-35','35-40','40+']
df['Age_bins'] = pd.cut(df['Age'], bins=bins, labels=labels)
df.head()

# %%
df['Income'].describe()

# %%
# Crosstabs -

cat_cols=['Gender','Education', 'MaritalStatus', 'Usage','Fitness','Age_bins','Income_bins','Mile_bins']
for i in cat_cols:
    other= round(pd.crosstab(df[df[i].notnull()][i], df['Product']).\
                 div(pd.crosstab(df[df[i].notnull()][i],df['Product']).apply(sum,1),0),2)
    ax = other.plot(kind ='bar', title = i, figsize = (10,4))
    ax.set_xlabel(i)
    ax.set_ylabel('Proportion')
    plt.xticks(rotation=45)
    plt.show()

# %%
from IPython.display import display
for i in cat_cols:
  print('Table for',str(i),'vs Treadmill Product')
  display(pd.crosstab(df[i], df['Product'], margins=True, normalize='index'))
  print("\n")

# %%
pd.crosstab(df['Product'],df['Gender'] )

# %%
sns.boxenplot(x='Gender',y='Age',data=df)
