# %% [markdown]
# <h1 style="font-family:verdana;"> <center>📚 Create Better &amp; Beautiful Notebooks : The Tutorial 📚</center> </h1>
# <p><center style="color:#159364; font-family:cursive;">Strive for Excellence, Not Perfection</center></p>
#
# ***

# %% [markdown]
# ![looking.png](attachment:looking.png)
# <cite>Image from www.dribbble.com by Anna Blagova</cite>

# %% [markdown]
# <div style="font-family:verdana;">
#     Font-Family: Verdana, Cursive<br>
#     Colors Used: ['crimson', 'orange', #202EF9, #FE1C0A, #159364]<br>
#     Emoji Used: [📚, 📌, 😃, 💬, 🎖, 📎, 🏆, 🗣, 🔭, 🌈, 💭, ⏳, 🙌🏻]<br>
#
# </div>

# %% [markdown]
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">This notebook is created for people who want to make their notebooks look <span style="color:crimson;">āesthetic</span> and more pleasing to the viewer. We are <span style="color:crimson;">not</span> going to solve any machine learning problem in this notebook (you can check my other notebooks for ML and EDA). We will only focus on the <span style="color:crimson;">HTML &amp; Markdown</span> to make your notebooks looks prettier and beutiful 🙌🏻 .</p><br>
#
#
# <div style="font-size:15px; font-family:verdana;">By the end of this notebook you will be able to:<br><br>
#
# <ol>
#     <li>Beautifully format your notebooks.</li>
#     <li>Learn how to use HTML and Markdown in kaggle notebooks.</li>
#     <li>Learn some good quotes.</li>
# </ol>
#
# </div>
#
# <br>
#
#
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana; line-height: 1.7em;">
#     📌 &nbsp; Please keep in mind that, I am a beginner and on my learning journey as most of you. I just want to share something that will be useful for many kagglers working hard on their notebooks. If you find this notebook useful in anyway, please upvote it so that it can reach a bigger audience. You can share it with your fellow kagglers.
# </div>
# <br><br>
# <blockquote><p style="font-size:16px; color:#159364; font-family:verdana;">💬 Finally, I would like to take this opportunity to remind everyone to be <code>kind</code>, <code>just</code> and <code>mindful</code>😃</p></blockquote>

# %% [markdown]
# ***

# %% [markdown]
# <h1 id="basics" style="font-family:verdana;">
#     <center>1. Simple Markdown 🎖
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#basics">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <p style="font-size:15px; font-family:verdana;">We will start with the <span style="color:crimson;">basic markdown</span> tutorial and then move on to working with HTML markup.<p>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="italic">
#         1.1 Making texts <i>italic</i>
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#italic">¶</a>
#     </h1>
#     <br>
#     <p>
#         There are three ways we can make our texts italic using simple markdown:<br>
#         <ol>
#             <li>using '-' before and after your text.<br><b>For ex:</b> <code>_this is italic_</code> becomes <i>this is italic</i></li>
#             <li>using '*' before and after your text.<br><b>For ex:</b> <code>*this is italic*</code> becomes <i>this is italic</i></li>
#             <li>we can use html italic tag "&lt;i&gt;&lt;/i&gt;" before and after your text.<br>For ex: <code>&lt;i&gt;this is italic&lt;/i&gt;</code> becomes <i>this is italic</i></li>
#         </ol>
#     </p>
# </div>

# %% [markdown]
# _MLV PRASAD_

# %% [markdown]
# *THIS IS MLV PRASAD*

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="bold">
#         1.2 Making texts BOLD
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#bold">¶</a>
#     </h1>
#     <br>
#     <p>
#         There are two ways we can make our texts bold using simple markdown:<br>
#         <ol>
#             <li>using '**' before and after your text.<br><b>For ex:</b> <code>**this is bold**</code> becomes <b>this is bold</b></li>
#             <li>we can surround our text by html bold tag "&lt;b&gt;&lt;/b&gt;".<br><b>For ex:</b> <code>&lt;b&gt;this is italic&lt;/b&gt;</code> becomes <b>this is bold</b></li>
#         </ol>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="strike">
#         1.3 <s>Strikethrough</s>
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#strike">¶</a>
#     </h1>
#     <br>
#     <p>
#         There are two ways we can make strikethrough texts:<br>
#         <ol>
#             <li>using '~~' before and after your text.<br><b>For ex:</b> <code>~~strikethrough~~</code> becomes <s>strikethrough</s></li>
#             <li>we can surround our text by html bold tag "&lt;s&gt;&lt;/s&gt;".<br><b>For ex:</b> <code>&lt;s&gt;strikethrough&lt;/s&gt;</code> becomes <s>strikethrough</s></li>
#         </ol>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="code">
#         1.4 Code formatting
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#code">¶</a>
#     </h1>
#     <br>
#     <p>
#         There are two ways we can format code in our notebook:<br>
#         <ol>
#             <li>
#                 <b>Simple Markdown</b>
#             </li>
#             <ul>
#                 <li>
#                     Use sigle backtick ( ` ) before and after the word to convert it into a special monospace format and stand out from other words.<br>
#                     For example: `print("Hello World!")` becomes:<br><code>print("Hello World!")</code>
#                 </li>
#                 <br>
#                 <li>
#                     For multiple lines, simply use three backticks ( ``` ) before and after the paragraph.<br>
#                     For example:<br>
#                     <pre>I cannot fix on the hour, or the spot, or the look or the words, which laid the foundation. It is too long ago. I was in the middle before I knew that I had begun.</pre>
#                 </li>
#             </ul>
#             <br>
#             <li>
#                 <b>HTML Markup</b>
#             </li>
#             <ul>
#                 <li>
#                     Alternatively, we can surround the word with html tag "&lt;code&gt;&lt;/code&gt;".<br>
#                     For example:<br>&lt;code&gt;print("Hello World!")&lt;/code&gt; becomes:<br><code>print("Hello World!")</code>
#                 </li>
#                 <br>
#                 <li>For multiple lines, you can surround your text in html tag <code>pre</code> ( "&lt;pre&gt;&lt;/pre&gt;" )</li><br>
#                 For example:<br>
#                 &lt;pre&gt;<br>
#                 It was times like these when I thought my father, who hated guns and had never been to any wars, was the bravest man who ever lived.<br>
#                 &lt;/pre&gt;
#                 <br><br>
#                 This becomes:
#                 <pre>It was times like these when I thought my father, who hated guns and had never been to any wars, was the bravest man who ever lived.</pre>
#             </ul>
#         </ol>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="header">
#         1.5 Creating headers (1-6)
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#header">¶</a>
#     </h1>
#     <br>
#     <p style="line-height:1.7em;">
#         There are six different types of header, <code>h1</code>, <code>h2</code>, <code>h3</code>, ..., <code>h6</code> in decreasing sizes with <code>h1</code> being the biggest and <code>h6</code> being the smallest header.<br>
#         We can simply create headers by adding <code>#</code> before the text. The number of <code>#</code> denotes the type of header.
#         <ol>
#             <li>Single <code>#</code> before text <code>#Header1</code> for <code>h1</code></li>
#             <li>Adding two <code>##</code> before text <code>##Header2</code> for <code>h2</code></li>.<br>.<br>.<br>
#             <li>Adding six <code>######</code> before text <code>######Header6</code> for <code>h6</code></li>
#         </ol>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="link">
#         1.6 Inserting links
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#link">¶</a>
#     </h1>
#     <br>
#     <p style="line-height:1.7em;">
#         To create an inline link, you wrap the link text in brackets <code>[ ]</code>, and then you wrap the link in parenthesis <code>( )</code>.<br><br>
#         For example, to create a <span style="color:crimson;">hyperlink</span> to my linkedin profile, with a link text that says, <i>Lets Connect on LinkedIn!</i>, you'd write this in Markdown:<br><code>[Lets Connect on LinkedIn!](https://www.linkedin.com/in/ksingh-shubh/)</code>.<br><br>
#         <a href="https://www.linkedin.com/in/ksingh-shubh/" target="_blank">Lets Connect on LinkedIn!</a>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="rule">
#         1.7 Horizontal rule
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#rule">¶</a>
#     </h1>
#     <br>
#     <p style="line-height:1.7em;">
#         A horizontal rule is a line that goes across a webpage.<br>
#         There are two ways to create a horizontal rule in your notebook:<br>
#         <ol>
#             <li>Simply type <code>***</code> in your notebook and run the markdown snippet.</li>
#             <li>Alternatively, you can use html horizontal rule tag <code>&lt;hr&gt;</code></li>
#         </ol>
#         <hr>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="image">
#         1.8 Inserting images 🌄
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#image">¶</a>
#     </h1>
#     <br>
#     <p style="line-height:1.7em;">
#         The difference between links and images is that images are prefaced with an exclamation point <code>!</code>.<br><br>
#         To create an inline image link, enter an exclamation point <code>!</code>, wrap the alt text in brackets <code>[ ]</code>, and then wrap the link in parenthesis <code>( )</code>.<br>(Alt text is a phrase or sentence that describes the image for the visually impaired.)<br>
#         For example, to create an inline image link to an image on <i>dribbble.com</i>, with an alt text that says, <i>Stay Home</i>, you'd write this in Markdown:<br><br>
#         <pre>![Stay Home](https://cdn.dribbble.com/users/18013/screenshots/12600021/media/3cb1d96666688e41589a638d48cd4674.png)</pre>
#         <br><br>
#     </p>
# </div>
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 If you have an offline image on your desktop and want to insert it to your notebook then simply drag and drop it in the markdown snippet.
# </div>

# %% [markdown]
# ![Stay Home](https://cdn.dribbble.com/users/18013/screenshots/12600021/media/3cb1d96666688e41589a638d48cd4674.png)
# <cite>Image from www.dribbble.com by Vitaliy Sokovikov</cite>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="block">
#         1.9 Blockquotes
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#block">¶</a>
#     </h1>
#     <br>
#     <p style="line-height:1.7em;">
#         If you need to call <span style="color:crimson;">special attention</span> to a quote from another source, or design a pull quote for a magazine article, then Markdown's blockquote syntax will be useful. A blockquote is a sentence or paragraph that's been specially formatted to draw attention to the reader.<br>For example:<br>
#     <blockquote>"The sin of doing nothing is the deadliest of all the seven sins. It has been said that for evil men to accomplish their purpose it is only necessary that good men should do nothing." </blockquote><br>
#     There are two ways to create a blockquote in your notebook:<br>
#     <ol>
#         <li>Preface a line with the "greater than" caret <code>></code></li>
#         <li>Alternatively, you can use html blockquote tag <code>&lt;blockquote&gt;&lt;/blockquote&gt;</code></li>
#     </ol>
#     For example:<br>
#     >Take a step back, look at the bigger picture
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="emoji">
#         1.10 Emoji 😃
#         <br>
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#emoji">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#     <ol>
#         <li>
#             <b>For Mac Users:</b> Simply press <code>control + command</code> and then hit <code>space</code> button.
#         </li>
#         <li>
#             <b>For Windows Users:</b> Simply press <code>Win + period (.)</code> or <code>Win + semicolon (;)</code>
#         </li>
#     </ol>
#     You will get a popup window from which you can choose any emoji you like. Sweet, isn't it?
#     </p>
# </div>

# %% [markdown]
# ![Screenshot%202020-07-03%20at%201.50.28%20PM.png](attachment:Screenshot%202020-07-03%20at%201.50.28%20PM.png)

# %% [markdown]
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📎 Take a look at this link for in-depth markdown tutorial: <a href="https://github.com/showdownjs/showdown/wiki/Showdown's-Markdown-syntax" target="_blank" style="color:orange;">In-depth Markdown Tutorial</a>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <h1 id="markup" style="font-family:verdana;">
#     <center>2. HTML Markup 🏆
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#markup">¶</a>
#     </center>
# </h1>

# %% [markdown]
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">
#     Alright, we have learnt about how we can format our notebooks using simple markdown. Now lets proceed further into <span style="color:crimson;">taking more control</span> of our notebook formatting with the help of HTML markdown. This adds up a broad range of options in your arsenal and makes you stand out from others.<br><br>Without any further ado, let us begin.
# </p>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="center">
#         2.1 Align Text in Center
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#center">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         You can use this on your main heading to make them stand out. There are two ways by which you can align your heading or text in center of the notebook (horizontally):
#         <ol>
#         <li>
#             All you have to do, is surround your text in html center tag <code>&lt;center&gt;&lt;/center&gt;</code>
#         </li>
#         <li>
#             Or, you can surround your text in paragraph <code>p</code> tag and then give it the css property of <code>text-align:center;</code><br><br>
#             For example: <code>&lt;p style="text-align:center;"&gt; I am in center &lt;/p&gt;</code> becomes:<br><br>
#             <p style="text-align:center;">I am in center</p>
#         </li>
#     </ol>
#     </p>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="family">
#         2.2 Change Font Family, Font Color, and Font Size
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#family">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         In this section, we will learn how to change font-family, font-color, and font-size.
#         <ol>
#             <li>
#                 <b>Change Font Family</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-family, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the family of font by <code>font-family</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="font-family:cursive;"&gt; Love for all, Hatred for none &lt;/span&gt;
#                     <br><br>
#                     <span style="font-family:cursive;">Love for all, Hatred for none</span>
#                 </li>
#             </ul>
#             <br>
#             <li>
#                 <b>Change Font Color</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-color, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the color of font by <code>color</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="color:crimson;"&gt; Doubt kills more dreams than failure ever will. &lt;/span&gt;
#                     <br><br>
#                     <span style="color:#159364;">Doubt kills more dreams than failure ever will.</span>
#                 </li>
#             </ul>
#             <li>
#                 <b>Change Font Size</b>
#             </li>
#             <ul>
#                 <li>
#                     To change the font-size, first you should surround your text in a html tag such as <code>span</code>, <code>p</code> and <code>div</code> and then you have to add the css <code>style</code> property inside the html tag. After this you can change the size of font by <code>font-size</code> property. Lets look at an example to make sense of all this:<br><br>
#                     &lt;span style="font-size:18px;"&gt; Find peace in the journey. &lt;/span&gt;
#                     <br><br>
#                     <span style="font-size:18px;">Find peace in the journey.</span>
#                 </li>
#             </ul>
#         </ol>
#     </p>
# </div>
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 <b>Line Break and Whitespaces:</b><br><br>You can add a line-break by html break tag <code>&lt;br&gt;</code> and you can add more whitespaces by <code>&amp;nbsp;</code>
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="callout">
#         2.3 Callout 🗣
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#callout">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         You can create a callout if you want to call out the <span style="color:crimson;">attention of your reader</span> to something important. It is a great way to express key points of any topic in your notebook.<br>
#         To create a callout 💭, follow these steps:<br>
#     <ol>
#         <li>
#             Create a <code>div</code> tag: &lt;div&gt; &lt;/div&gt;
#         </li>
#         <li>
#             create a <code>class</code> attribute inside the dive tag and give it a value of <code>"alert alert-block alert-info"</code>
#         </li>
#     </ol>
#     Write whatever you want inside the <code>div</code> tag and you are good to go.<br><br>Lets look at an example:<br>
#     <pre>&lt;div class="alert alert-block alert-info"&gt; 📌 Please note that class="alert alert-block alert-info" is a pre-defined class by kaggle and we are simply using it in our notebook.&lt;/div&gt;</pre>
#     becomes:
#     </p>
# </div>
# <div class="alert alert-block alert-info" style="font-size:14px; font-family:verdana;">
#     📌 Please note that class="alert alert-block alert-info" is a pre-defined class by kaggle and we are simply using it in our notebook.
# </div>

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="heading">
#         2.4 Add links for your headings 🔭
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#heading">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         Your heading (h1) appears on the right side of your notebook after publishing it. So that people can <span style="color:crimson;">easily navigate</span> through your notebook.<br>
#         But when you use html in your markdown snippet and use the <code>h1</code> instead of <code>#</code> to create beautiful headings, kaggle does not show it on the right side of screen. You can change this to make your readers life a bit easier.<br>Lets us look at how we can do this:<br>
#     <ol>
#         <li>
#             Create a <code>h1</code> tag and inside it write down your heading.
#         </li>
#         <li>
#             Create an <code>id</code> attribute in your <code>h1</code> tag and give it any value you want. <code>id="hello"</code>
#         </li>
#         <li>
#             Now, create an anchor tag <code>a</code> inside the <code>h1</code> tag, just after your heading and give a <code>class</code> attribute the value of <code>"anchor-link"</code>.
#         </li>
#         <li>
#             Add one more attribute to your anchor tag, <code>href</code> and give it the value of your notebook link followed by a <code>#</code> and the name of id in second step.<br>
#             It would look something like this:
#             <pre>https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#hello</pre>
#         </li>
#         <li>
#             Finally, add this symbol <code>¶</code> in your anchor tag.
#         </li>
#     </ol>
#     This one seems a bit complicated, but its very easy. You will get a bigger picture by looking at the example below:<br>
#     <pre>&lt;h1 id="heading"&gt;<br>My first heading<br>&lt;a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#heading"&gt;¶&lt;/a&gt;<br>&lt;/h1&gt;</pre>
#     <br><br>
#     </p>
# </div>
# <p style="font-family:verdana; word-spacing:1.5px;">
#     All your <code>h1/#</code> headers appear on right side of your notebook as the figure below:
# </p>

# %% [markdown]
# ![table.png](attachment:table.png)

# %% [markdown]
# <div style="font-family:verdana; word-spacing:1.5px;">
#     <h1 id="beauty">
#         2.5 Make Beautiful Text Box 🌈
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#beauty">¶</a>
#     </h1>
#     <p style="line-height:1.7em;">
#         This is similar to Callout, but the big difference is that this time we are <span style="color:crimson">taking control</span> and we will be designing the text box for important messages. So without any hassle, lets just get into it:<br><br>
#         By far, we have learnt a lot about using <span style="color:crimson;">html markdown</span> in our notebook. We will just add more knowledge to that understanding to create a textbox of our imagination.
#     <ol>
#         <li>
#             Simply create a <code>p</code> tag inside a <code>div</code> tag.
#         </li>
#         <li>
#             Write your heart out in the paragraph <code>p</code> tag.
#         </li>
#         <li>
#             Finally, the most important thing is the CSS styling in our html tags.
#         </li>
#     </ol>
#     <br>
#     Lets take a look at this example:<br>
#     <pre>&lt;div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px"&gt;<br>
# &lt;p style="padding: 10px;
#               color:white;"&gt;<br>
#               All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.
# &lt;/p&gt;
# &lt;/div&gt;</pre>
#     <br>
#     Will Become:<br><br>
#     <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:110%;
#            font-family:Verdana;
#            letter-spacing:0.5px">
#         <p style="padding: 10px;
#               color:white;">
#             All that is gold does not glitter,Not all those who wander are lost;The old that is strong does not wither,Deep roots are not reached by the frost.
#         </p>
#     </div>
#     </p>
# </div>

# %% [markdown]
# ***

# %% [markdown]
# <h1 id="final">
#         Finally... 💭
#         <a class="anchor-link" href="https://www.kaggle.com/shubhamksingh/formatting-notebooks-tutorial-html-markdown/notebook#final">¶</a>
#     </h1>
# <p style="font-size:15px; font-family:verdana; line-height: 1.7em">
#     As you can see, there is so much that we can do with our notebooks. Just because of the fact that we can use <span style="color:crimson;">html</span> to format our notebooks, we gain ultimate power over formatting our notebooks. There is so much more that you can do to make your notebook look amazing. Its upto you how you use this feature and what ideas you come up with to give your notebook that sweet <span style="color:crimson;">aesthetic</span> look.<br><br>
#     Feel free to use this notebook as a reference when you work on a new notebook. I hope that this notebook helps all my fellow kagglers in some way.
#     <br><br>
#     I will keep updating this notebook ⏳
#     <br><br>
#     <center style="font-family:cursive; font-size:18px; color:#159364;">Keep creating beautiful and meaningful notebooks, and do not forget to be kind and mindful.</center>
# </p>
#
# ***
